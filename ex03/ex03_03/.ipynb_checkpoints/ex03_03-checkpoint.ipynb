# %%
My:

# %%
import json

def separation(line, unit_list=[]):
    for i_unit in range(len(line)):
        if line[i_unit].isupper():
            if (i_unit + 1) < len(line) and line[i_unit + 1].islower():
                unit = line[i_unit] + line[i_unit + 1]
            else:
                unit = line[i_unit]
            unit_list.append(unit)
    return unit_list

with open('import_file_3.txt') as file:
    line = file.readline()
    unit_list = separation(line)

periodic_table = json.load(open('periodic_table.json'))

res_list = ''
for i_list in unit_list:
    res_list += str(periodic_table.get(i_list))

    with open('output_file_3.txt', 'a') as output_file:
        output_file.write(str(res_list))

# %%
The best:

# %%
import json

periodic_table = json.load(open('/home/venus/Serg/Coding/open-ml/ex03/ex03_03/periodic_table.json'))

text = open('/home/venus/Serg/Coding/open-ml/ex03/ex03_03/import_file_3.txt', 'rt').read()

# %%
periodic_table['I']
# Out:
# 'Йод'

# %%
re.findall(r'[A-Z][a-z]*', elements) #Regular expression
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 re.findall(r'[A-Z][a-z]*', elements)
#
# NameError: name 'elements' is not defined

# %%
import re

print(''.join(map(lambda el: periodic_table[el], re.findall(r'[A-Z][a-z]*', elements))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <module>
#       1 import re
# ----> 3 print(''.join(map(lambda el: periodic_table[el], re.findall(r'[A-Z][a-z]*', elements))))
#
# NameError: name 'elements' is not defined

# %%
One more:
# Out:
#   Input In [30]
#     One more:
#         ^
# SyntaxError: invalid syntax

# %%
for k, v in periodic_table.items():
    text = text.replace(k, v)

# %%
text
# Out:
# 'УглеродrУглеродoРадийЛитийБорhМарганецМенделевийСераmАзотhФосфорbУглеродaУранУранМолибденЙодrФосфорoЕвропийУглеродФосфорmФосфорoРубидийФосфорuКислородsЛоуренсийАргонУглеродmФосфорdУглеродeАзотБорkБорaЛантанУглеродuМышьякУглеродfФосфорrУглеродdБорaАзотdАлюминийАлюминийРутенийБорaТаллийФторlУранueТеннессинРадонУглеродeУглеродrВодородfФосфорmЛантанФосфорbМенделевийУглеродfБорrБорkФосфорrГадолинийЭйнштейнийУранУглеродfАзотeМагнийСераmЛантанБорhЛютецийДармштадтийМолибденСераmАлюминийКислородФосфорbДубнийУглеродuУглеродeЭйнштейнийЭйнштейнийКсенонУглеродaМенделевийВодородeСераbЛиверморийТорийАстатФторРутенийАзотbФосфорrЛитийУглеродuЛантанАзотiИттрийbМенделевийУглеродlАргонФосфорmАктинийТулийГадолинийАстатЛиверморийСераrАзотdСераcТулийФторМагнийУранueТеннессинФосфорdБорrСераmРутенийКислородТеллурАктинийЛютецийВодородsТулийУранueИттрийbМарганецУглеродВодородfДиспрозийФосфорbРадийСераeФосфорmВодородfАлюминийКалийАзотИттрийВодородgФосфорrКсенонВольфрамВодородТеннессинАстатВодородsГерманийМышьякРазерфордийФосфорoТаллийСераМолибденЛиверморийВодородgМосковийРутенийУглеродТеннессинЛоуренсийВодородsФосфорoРодийИттрийbМышьякЭрбийТулийЙодТитанАлюминийСераgАзотФторВанадийАзотpУглеродuУглеродdСераmАстатФторeАзотdГалийФторЛитийБорrЙодnБорhКислородsЕвропийАзотbЛитийЙодrФторlМолибденФторlУглеродuЛантанМосковийКалийСераeАзотiУглеродdУглеродmМышьякСераСераeТулийФторrФосфорoАзотiТеллурСераrМолибденЭрбийФосфорt